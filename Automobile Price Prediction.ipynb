# %% [markdown]
# # BUSINESS CASE: BASED ON THE GIVEN FEATURE OF DATASET WE NEED TO PREDICT THE AUTOMOBILE PRICE

# %% [markdown]
# ## IMPORT BASIC LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## LOAD DATA

# %%
column_names = ["Symboling", "Normalized-Losses", "Make", "Fuel-Type", "Aspiration","Num-of-Doors", "Body-Style", "Drive-Wheels", "Engine-Location","Wheel-Base", "Length", "Width", "Height", "Curb-Weight","Engine-Type", "Num-Of-Cylinders", "Engine-Size", "Fuel-System","Bore", "Stroke", "Compression-Ratio", "Horsepower", "Peak-rpm","City-mpg", "Highway-mpg", "Price"]

data = pd.read_csv("auto_imports.csv", names=column_names)
pd.set_option("display.max_columns", None)
data.head()
# Out:
#    Symboling Normalized-Losses         Make Fuel-Type Aspiration Num-of-Doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     Body-Style Drive-Wheels Engine-Location  Wheel-Base  Length  Width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# ## DOMAIN ANALYSIS

# %% [markdown]
# **1. Symboling:**
#
# - Symboling is a numerical representation of the risk associated with a vehicle. It typically ranges from -3 to +3, where negative values indicate a lower risk, and positive values indicate a higher risk. It can be used by insurance companies to determine insurance premiums.
# - **Symboling Values:**
#
# - **"-3":** This value indicates that the car is considered to have the highest risk.
# - **"-2":** Similarly, vehicles with a Symboling of -2 are also considered to have a relatively high risk.
# - **"-1":** Cars with a Symboling of -1 still carry an above-average risk, although it's slightly lower than those with -2 or -3.
# - **"0":** A Symboling of 0 indicates a vehicle with an average level of risk. It's considered a neutral point in terms of insurance risk.
# - **"+1, +2, +3":** These positive values indicate cars with progressively lower risk. A Symboling of +3 corresponds to vehicles with the lowest perceived risk.
#
# **2. Normalized-Losses:**
#
# - Normalized-Losses is a feature in automobile dataset that represents normalized insurance losses in monetary terms. This feature provides insights into the average loss payment per insured vehicle year, normalized for different car models.
#
# **3. Make:**
#
# - The Make feature in automobile dataset refers to the manufacturer or brand of the vehicle. It's a categorical feature that provides information about the company that produced the car.
# - The "Make" feature represents the name of the car manufacturer or brand, such as "Toyota", "Honda","BMW" and so on.
#
# **4. Fuel-Type:**
# - The Fuel Type feature in a dataset refers to the type of fuel used to power vehicles. It's a categorical attribute that classifies vehicles based on the energy source they rely on for their engines.
# - The two main categories are usually "Diesel" and "Gas" fuel.
# - **Diesel Fuel:**
# - Diesel engines run on diesel fuel, which is less refined than gas. Diesel vehicles tend to be more fuel-efficient and have better torque, making them suitable for heavy-duty applications.
# - **Gas Fuel:**
# - Gas engines use gas as their primary fuel source. Gas is more commonly used for everyday vehicles and has different combustion characteristics compared to diesel.
#
# **5. Aspiration:**
#
# - The Aspiration feature in a dataset for automobiles refers to the type of air intake system used in the vehicle's engine. It's a categorical attribute that indicates whether the engine is naturally aspirated or equipped with a turbocharger for forced induction.
# - "Aspiration" classifies engines into two main categories: "Standard" (often denoted as "std") and "Turbocharged" (often denoted as "turbo").
# - **Standard (Naturally Aspirated) Engines:**
# - Engines with standard aspiration rely on the natural atmospheric pressure to draw in air during the intake stroke.
# - **Turbocharged Engines:**
# - Turbocharged engines have a turbocharger, which is a device that forces additional air into the engine's cylinders.
#
#
# **6. Num-of-Doors:**
#
# - The Num-of-Doors feature in a dataset refers to the number of doors a vehicle has. It's a categorical attribute that provides information about the physical design of the vehicle's cabin.
# - The "Num-of-Doors" feature indicates how many doors a vehicle has. It's a categorical variable that typically has two possible values: "Two" and "Four."
#
# **7. Body-Style:**
#
# - The Body Style feature in an automobile dataset refers to the specific design or configuration of the vehicle's exterior and structure. It's a categorical attribute that categorizes vehicles based on their overall shape and appearance.
# - Represents the body style of the car (sedan, hatchback, etc.).
#
# **8. Drive-Wheels:**
#
# - The Drive Wheels feature in an automotive dataset refers to the configuration of wheels that are responsible for propelling the vehicle. It's a categorical attribute that provides information about how power is distributed to the wheels.
# - The main categories are
# - 1."4WD" (Four-Wheel Drive)- Four-wheel drive distributes power to all four wheels, which can improve traction on various terrains.
# - 2."FWD" (Front-Wheel Drive)- In a front-wheel drive configuration, the engine's power is transmitted to the front wheels.
# - 3."RWD" (Rear-Wheel Drive)- In a rear-wheel drive configuration, the engine's power is sent to the rear wheels.
#
# **9. Engine-Location:**
#
# - The Engine Location feature in a dataset refers to the position where the engine of a vehicle is located within the vehicle's chassis. It's a categorical attribute that provides information about the arrangement of the engine.
# - **Front Engine:**
# - The most common engine location is at the front of the vehicle. In front-engine vehicles, the engine is positioned in the front compartment, usually under the hood.
# - **Rear Engine:**
# - In rear-engine vehicles, the engine is located at the rear of the vehicle, typically behind the rear axle.
#
# **10. Wheel-Base:**
#
# - Wheel Base is a key feature in your automobile dataset that refers to the distance between the centers of the front and rear wheels of a vehicle. This measurement provides insights into the vehicle's stability, handling, and overall dimensions.
#
#
# **11. Length:**
#
# -  the Length feature represents the length of a vehicle. It's a numerical attribute that provides information about the physical dimensions of the car.
#
# **12. Width:**
#
# - The Width feature in your automobile dataset refers to the width of the vehicle. It's a numerical attribute that provides information about the horizontal dimensions of a car.
#
# **13. Height:**
#
# - The Height feature in your automobile dataset refers to the vertical measurement of the vehicle from the ground to its highest point.
#
# **14. Curb-Weight:**
#
# - Curb Weight is an important feature in your automobile dataset that refers to the weight of a vehicle when it's fully equipped with all standard items, including essential fluids, fuel, and a full complement of passengers and cargo.
#
#
# **15. Engine-Type:**
#
# - The Engine Type feature in your automobile dataset describes the type of engine used in each vehicle. It's a categorical attribute that provides information about the configuration and design of the internal combustion engine.
# - Represents the type of engine (dohc, ohc, etc.).
#
# **16. Num-Of-Cylinders:**
#
# - Indicates the number of cylinders in the engine.
# - The Num-of-Cylinders feature in your automobile dataset indicates the number of cylinders in the engine of each vehicle. It's a categorical feature that provides information about the internal combustion configuration of the engine.
#
# **17. Engine-Size:**
#
# - Represents the size of the engine in cubic centimeters.
# - The Engine Size feature in your automobile dataset refers to the displacement volume of an engine. It's a numerical attribute that provides information about the capacity of the engine's combustion chambers.
#
# **18. Fuel-System:**
#
# - Represents the type of fuel system.
# - The Fuel-System feature in your automobile dataset provides information about the type of fuel delivery system used in the vehicle's engine. It's a categorical feature that offers insights into how fuel is mixed and delivered to the engine for combustion.
#
# **19. Bore:**
#
# - Bore is a feature commonly found in automobile datasets that represents the diameter of each cylinders in an engine. It's a crucial parameter that directly influences the engine's performance, efficiency, and overall characteristics.
#
# **20.Stroke:**
#
# - Stroke is a feature that appears to be related to engine specifications in your automobile dataset. It represents the length of the piston stroke within an engine.
#
#
# **21.Compression-Ratio:**
#
# - Stroke is the distance that the piston travels inside the cylinder during the engine's operation. It affects engine displacement and performance.
#
# **22. Horsepower:**
#
# - Horsepower is a term used to measure the engine's power output, particularly in vehicles like cars, motorcycles, and other machinery. It's a critical metric that indicates the engine's ability to perform work over time.
#
# **23. Peak-rpm:**
#
# -  Peak RPM is a feature in automobile dataset that represents the engine speed at which the engine delivers its maximum power output. It's an important metric for understanding the performance characteristics of a vehicle's engine.
#
# **24. City-mpg:**
#
# - City-mpg, short for "city miles per gallon," is a feature in automobile dataset that provides information about a vehicle's fuel efficiency when driven in city conditions. It measures how many miles a car can travel on average per gallon of fuel consumed while driving in urban or city settings.
#
# **25. Highway-mpg:**
# - Highway-mpg is a feature in automobile dataset that represents a measure of fuel efficiency for a vehicle when driving on the highway. This feature provides insights into how many miles a car can travel per gallon of fuel consumed on highways.
#
# **26. Price:**
# - Price is a fundamental and critical feature in automobile dataset that represents the cost of a vehicle. This feature provides valuable insights into the financial aspect of different car models and is a key factor influencing purchasing decisions.
# - Price is Target variable, typically in a specified currency (e.g., USD).

# %% [markdown]
# ## BASICS CHECKS

# %%
data.head()
# Out:
#    Symboling Normalized-Losses         Make Fuel-Type Aspiration Num-of-Doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     Body-Style Drive-Wheels Engine-Location  Wheel-Base  Length  Width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
data.tail()
# Out:
#      Symboling Normalized-Losses   Make Fuel-Type Aspiration Num-of-Doors  \
# 196         -1                95  volvo       gas        std         four
# 197         -1                95  volvo       gas      turbo         four
# 198         -1                95  volvo       gas        std         four
# 199         -1                95  volvo    diesel      turbo         four
# 200         -1                95  volvo       gas      turbo         four
#
#     Body-Style Drive-Wheels Engine-Location  Wheel-Base  Length  Width  \
# 196      sedan          rwd           front       109.1   188.8   68.9
# 197      sedan          rwd           front       109.1   188.8   68.8
# 198      sedan          rwd           front       109.1   188.8   68.9
# 199      sedan          rwd           front       109.1   188.8   68.9
# 200      sedan          rwd           front       109.1   188.8   68.9
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# ...

# %%
data.shape
# Out:
# (201, 26)

# %% [markdown]
# * The dataset contain 201 observation with 26 feature.

# %%
data.columns
# Out:
# Index(['Symboling', 'Normalized-Losses', 'Make', 'Fuel-Type', 'Aspiration',
#        'Num-of-Doors', 'Body-Style', 'Drive-Wheels', 'Engine-Location',
#        'Wheel-Base', 'Length', 'Width', 'Height', 'Curb-Weight', 'Engine-Type',
#        'Num-Of-Cylinders', 'Engine-Size', 'Fuel-System', 'Bore', 'Stroke',
#        'Compression-Ratio', 'Horsepower', 'Peak-rpm', 'City-mpg',
#        'Highway-mpg', 'Price'],
#       dtype='object')

# %% [markdown]
# * Total 26 feature is present in the dataset including target variable i.e Price

# %%
data.dtypes
# Out:
# Symboling              int64
# Normalized-Losses     object
# Make                  object
# Fuel-Type             object
# Aspiration            object
# Num-of-Doors          object
# Body-Style            object
# Drive-Wheels          object
# Engine-Location       object
# Wheel-Base           float64
# Length               float64
# Width                float64
# Height               float64
# Curb-Weight            int64
# Engine-Type           object
# Num-Of-Cylinders      object
# Engine-Size            int64
# Fuel-System           object
# Bore                  object
# Stroke                object
# Compression-Ratio    float64
# Horsepower            object
# Peak-rpm              object
# City-mpg               int64
# Highway-mpg            int64
# Price                  int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          201 non-null    int64
#  1   Normalized-Losses  201 non-null    object
#  2   Make               201 non-null    object
#  3   Fuel-Type          201 non-null    object
#  4   Aspiration         201 non-null    object
#  5   Num-of-Doors       201 non-null    object
#  6   Body-Style         201 non-null    object
#  7   Drive-Wheels       201 non-null    object
#  8   Engine-Location    201 non-null    object
#  9   Wheel-Base         201 non-null    float64
#  10  Length             201 non-null    float64
#  11  Width              201 non-null    float64
#  12  Height             201 non-null    float64
#  13  Curb-Weight        201 non-null    int64
#  14  Engine-Type        201 non-null    object
#  15  Num-Of-Cylinders   201 non-null    object
# ...

# %% [markdown]
# * Here we can clearly seen that the some feature has contain speacial character, So we are replace this character with NaN.

# %%
# Replace special character with NaN
data.replace('[!@#?/]', np.nan, regex=True, inplace=True)

# %%
# Change the data type of feature 
data[["Normalized-Losses","Bore","Stroke","Horsepower","Peak-rpm"]]=data[["Normalized-Losses","Bore","Stroke","Horsepower","Peak-rpm"]].apply(pd.to_numeric)
print(data.dtypes)
# Out:
# Symboling              int64
# Normalized-Losses    float64
# Make                  object
# Fuel-Type             object
# Aspiration            object
# Num-of-Doors          object
# Body-Style            object
# Drive-Wheels          object
# Engine-Location       object
# Wheel-Base           float64
# Length               float64
# Width                float64
# Height               float64
# Curb-Weight            int64
# Engine-Type           object
# Num-Of-Cylinders      object
# Engine-Size            int64
# Fuel-System           object
# Bore                 float64
# Stroke               float64
# Compression-Ratio    float64
# Horsepower           float64
# Peak-rpm             float64
# City-mpg               int64
# Highway-mpg            int64
# Price                  int64
# dtype: object

# %% [markdown]
# ### NUMERICAL FEATURES

# %%
num_data=data.select_dtypes(include=["int64","float64"])
num_data.columns
# Out:
# Index(['Symboling', 'Normalized-Losses', 'Wheel-Base', 'Length', 'Width',
#        'Height', 'Curb-Weight', 'Engine-Size', 'Bore', 'Stroke',
#        'Compression-Ratio', 'Horsepower', 'Peak-rpm', 'City-mpg',
#        'Highway-mpg', 'Price'],
#       dtype='object')

# %% [markdown]
# ### CATEGORICAL FEATURES

# %%
cat_data=data.select_dtypes(include=["O"])
cat_data.columns
# Out:
# Index(['Make', 'Fuel-Type', 'Aspiration', 'Num-of-Doors', 'Body-Style',
#        'Drive-Wheels', 'Engine-Location', 'Engine-Type', 'Num-Of-Cylinders',
#        'Fuel-System'],
#       dtype='object')

# %% [markdown]
# ###  UNIQUE CATEGORICAL FEATURES

# %%
for i in cat_data:
    print(i,cat_data[i].unique())
    print(cat_data[i].value_counts())
    print("--------------------------")
# Out:
# Make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: Make, dtype: int64
# --------------------------
# Fuel-Type ['gas' 'diesel']
# gas       181
# diesel     20
# Name: Fuel-Type, dtype: int64
# --------------------------
# Aspiration ['std' 'turbo']
# std      165
# turbo     36
# Name: Aspiration, dtype: int64
# ...

# %% [markdown]
# ### STATISTICAL MEASURES OF NUMERICAL DATA

# %%
data.describe().T
# Out:
#                    count          mean          std      min      25%  \
# Symboling          201.0      0.840796     1.254802    -2.00     0.00
# Normalized-Losses  164.0    122.000000    35.442168    65.00    94.00
# Wheel-Base         201.0     98.797015     6.066366    86.60    94.50
# Length             201.0    174.200995    12.322175   141.10   166.80
# Width              201.0     65.889055     2.101471    60.30    64.10
# Height             201.0     53.766667     2.447822    47.80    52.00
# Curb-Weight        201.0   2555.666667   517.296727  1488.00  2169.00
# Engine-Size        201.0    126.875622    41.546834    61.00    98.00
# Bore               197.0      3.330711     0.270793     2.54     3.15
# Stroke             197.0      3.256904     0.319256     2.07     3.11
# Compression-Ratio  201.0     10.164279     4.004965     7.00     8.60
# Horsepower         199.0    103.396985    37.553843    48.00    70.00
# ...

# %% [markdown]
# #### INSIGHTS:

# %% [markdown]
# - This indicates that some features have missing values in "Normalized-Losses" , "Bore" , "Stroke","Horsepower","Peak-rpm").
# - The average "Symboling" value is 0.84, and the average "Curb-Weight" is 2555.67 pounds.
# - The "Symboling" feature's values range from -2 to 3, with an average close to 0. This suggests a mix of risk levels in the dataset.
# - The "Curb-Weight" feature has relatively low variation (as indicated by the standard deviation) compared to "Price," which has significant variability.
# - "City-mpg" and "Highway-mpg" have differing ranges, indicating different fuel efficiency levels between city and highway driving.
# - "Normalized-Losses," "Bore," and "Stroke" have missing values, which might need to be addressed during data preprocessing.
# - "Engine-Size" varies widely, with a maximum value of 326 cubic centimeters.
# - "Price" exhibits a wide range, suggesting different pricing categories in the dataset.

# %% [markdown]
# ### STATISTICAL MEASURES OF CATEGORICAL DATA

# %%
data.describe(include="O")
# Out:
#           Make Fuel-Type Aspiration Num-of-Doors Body-Style Drive-Wheels  \
# count      201       201        201          199        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          113         94          118
#
#        Engine-Location Engine-Type Num-Of-Cylinders Fuel-System
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %% [markdown]
# ## EXPLORATORY DATA  ANALYSIS

# %% [markdown]
# ### 1.Univariate  Data Analysis

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# #### Observation/Insights

# %% [markdown]
# **1. Symboling**
# - The values of the Symboling feature range from -3 to +3, and they convey different levels of risk.
# - A Symboling of 0 indicates a vehicle with an average level of risk.
# - Similarly, vehicles with a Symboling of 1 are also considered to have a relatively high risk as compared to other.
#
# **2. Normalized-Losses**
# - The dataset's Normalized-Losses range from 65 to 265.
# - Average of Normalized-Losses is 122.
# - The distribution of the data is skewed.
#
# **3.Make**
# - Toyota have high count compared to other brands suggests that it's one of the dominant brands in the data.
# - Toyota appears to be the most common brand, followed by Nissan, Mazda, and Mitsubishi.
# - popularity of certain brands within specific vehicle brands like Subaru and Volkswagen are often associated with compact cars, while brands like Mercedes-Benz and BMW are known for luxury vehicles.
#
# **4. Fule-Type**
# - The Fule data indicates that the majority of the vehicles powered by gas, with a count of 181 vehicles.
# - Diesel-powered vehicles are less common, with a count of 20 vehicles.
# - Hence data is imbalanced.
#
# **5. Aspiration**
# - Out of the total Aspiration data represent the number of 165 counts(82%) of std" (presumably naturally aspirated) engines are present.
# - The number of 36 counts(18%) of "turbo" (presumably turbocharged) engines are present.
#
# **6. Num-of-Doors**
# - There are 113(57%) of vehicles with four doors as compared to those with two doors 85(43%).
# - The higher count of four-door vehicles suggests that they might be more common in the context it represents.
#
# **7. Body-Style**
# - Sedan body style is the most common among the 94(47%) of vehicles in the dataset. This suggests that sedans are Majority as compared to other vehicles.
# - Hatchback is the second common body style with 68(34%) Vehicles.
# - Wagon body style follows with 25 vehicles.
#
# **4.Hardtop and convertible:**
# - Hardtop and convertible body styles are less common, with 8 and 6 Vehicles respectively.
#
#
# **8. Drive-Wheels:**
# - The majority of vehicles in the data have front-wheel drive (118)59% of vehicles.
# - While less common, there is a substantial number of vehicles with rear-wheel drive (75)37% vehicles.
# - A smaller number of vehicles (8)4% vehicles have four-wheel drive (4WD).
#
# **9. Engine-Location:**
# - The majority of vehicles in the dataset have their engines located at the front (198 vehicles). This indicates that, within this dataset, front-engine is more common.
# - Vehicles with rear-engine placement are quite rare in this dataset, comprising only 3 vehicles. This suggests that the dataset is less common to front-engine vehicles.
#
# **10. Wheel-Base**
# - The Maximum range of Vehicle Wheel-Base is 120.
# - The Minimum range of Vehicle Wheel-Base is 86.6.
# - It is a normally skewed.
# - The Average of Width is 98.8.
#
# **11. Length**
# - The range of Vehicle length between 141 to 208.
# - It is a normally distributed.
# - The Average of length is 174.2.
#
# **12. Width**
# - The range of Vehicle Width between 60 to 72.
# - It is a normally distributed.
# - The Average of Width is 65.9.
#
# **13. Height**
# - The range of Vehicle Height between 47 to 59.
# - It is a normally distributed.
# - The Average of Width is 53.8.
#
# **14. Curb-Weight**
# - The data spans from a minimum value of 1,488 to a maximum value of 4,066.
# - The average of Curb-weight is 2,556 and median is 2,414 are indicating that the data distribution might be relatively symmetric.
#
# **15. Engine-Type**
# - The most common engine type is "ohc" (Overhead Camshaft) with 145 Vehicles, "ohcf" (Overhead Camshaft Front) with 15 vehicles, and "ohcv" (Overhead Camshaft Valve) with 13 vehicles.
# - The high count of "ohc" engines.
#
# **16. Num-Of-Cylinders**
# -  The majority of vehicles in the data have four cylinders (157 vehicles). This suggests that four-cylinder engines are more common in the types of vehicles.Four-cylinder engines are often used in smaller cars.
# - Vehicles with more cylinders, such as six, eight, or twelve, are generally found in larger vehicles or high-performance cars.
#
# **17. Engine-Size**
# - The dataset covers a substantial range of values, from a minimum of 61 to a maximum of 326.
# - The average is 127 and median is 120 it indicating that the data distribution skwed.
#
# **18. Fuel-System**
# - The majority of vehicles in this data use the Multi-Point Fuel Injection (MPFI) system for 92 vehicles. This suggests that MPFI is a common and popular fuel system among these vehicles.
# - The second most common fuel system is the 2-Barrel Carburetor (2bbl), which is found in 64 vehicles.
# - Diesel-powered vehicles using the Indirect Injection (IDI) system are present in 20 vehicles.
#
# **19. Bore**
# - The data spans from a minimum value of 2.54 to a maximum value of 3.94.
# - The average is 3.33 and median is 3.31 it indicating that the data distribution might be relatively symmetric.
#
# **20. Stroke**
# - The data spans from a minimum value of 7.0 to a maximum value of 23.0.
# - The average is 10.2 and median is 9.0 median is smaller than the average indicates a positive skew in the data.
#
# **21. Compression-Ratio**
# - The data spans from a minimum value of 7.0 to a maximum value of 23.0.
# - The average is 10.2 and median is 9.0 its indicates a positive skew in the data.
#
# **22. Horsepower**
# - The data spans from a minimum value of 48 to a maximum value of 177.
# - The average is 103 and median is 116 its suggesting that the data might be normally distributed or only slightly skewed.
#
# **23. Peak-rpm**
# - The dataset's Peak-rpm range from 4150 to 6600.
# - Average of Peak-rpm is 5118.
# - The distribution of the data is skewed.
#
# **24. City-mpg**
# - The City-mpg range from 13 to 49.
# - Average City-mpg is 25.2.
# - The distribution of the data is skewed.
#
# **25. Highway-mpg**
# - The dataset's Highway-mpg range from 16 to 54.
# - Average of Highway-mpg is 30.7.
# - The distribution of the data is Normally distributed.
#
# **26. Price**
# - The Price range from 5118 to 45400.
# - Average Price is 13207.
# - The distribution of the data is skewed.

# %% [markdown]
# ### 2. Bivariate  Data Analysis

# %% [markdown]
# #### RELATIONSHIP OF INDEPENDANT FEATURE WITH RESPECT TO TARGET FEATURE

# %%
plt.figure(figsize=(16,20),facecolor="white")
plotnumber=1

for column in num_data.drop("Price",axis=1):
    if plotnumber<=len(num_data):
        plt.subplot(5,3,plotnumber)
        sns.set_style("darkgrid", {"grid.color": ".7", "grid.linestyle": ":"})
        sns.lineplot(x=num_data[column],y='Price',data=data,color='red')
        plt.xlabel(column,fontsize=15)
        plt.ylabel("Price",fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Observation/Insights
#
# #### 1.Relationship between Symboling & Price
# - Cars with symboling values of -1, -2, and 3 having high prices vehicles. On the other hand, cars with different symboling values related priced are lower.
#
# #### 2.Relationship between Normalize-Losses & Price
# - Cars with normalized losses between 130 and 150 this range is tend show higher price of vehicles.
# - normalized losses tend suddenly becomes high at a particular point,at that point vehicle prices are high.
# - suddenly becomes low vehicles prices are also low.
# - 140 is the highest point where the price is very high.
#
# #### 3.Relationship between Wheel Base & Price
# - In this Graph it is seen that graph is increasing but suddenly some points have high price and suddenly some points are showing low price of vehicles.
# - This graph is increase range from 103 to 120.
# - smaller wheelbases range from 85 to 90 the car prices are lower.
# - larger wheelbases range from 115 to 120 their are higher price of car.
#
# #### 4.Relationship between Length & Price
# - length of the cars increases corresponding price will be increase.
# - 140 is the lowest length where the price is very low.
# - 200 is the highest length where the price is very high.
# - There is a positive relationship between length and price.
#
# #### 5.Relationship between  Width & Price
# - This graph is seen increasing. width of cars increases corresponding price will be increase.
# - 60 is the lowest width where the price is very low.
# - 72 is the highest width where the price is very high.
# - There is a positive relationship between width and price.
#
# #### 6.Relationship between  Height & Price
# - height of cars decreases tendency to increase car price. This graph show inverse relationship.
# - 48 is the lowest Height where the price is High.
# - 60 is the highest Height where the price is low.
#
# #### 7.Relationship between Curb Weight & Price
# - Curb weight of cars increases corresponding increases there car price.This graph show positive relationship between curb weight and price.
# - range from 2700 to 2000 curb weight there is high trends
#
# #### 8.Relationship between Engine Size & Price
# - Larger engine sizes there car price generally high. Its positive relation between Engine size and price of car.
# - The price is higher in the range 200 to 300 engine size.
#
# #### 9.Relationship between Bore & Price
# - bore diameter is increases there car price generally high. Its show postive trend.
# - The Bore diameter range from 3.6 to 4.0 in this case the price of car is high.
#
# #### 10.Relationship between Stroke & Price
# - Larger stroke sizes there tends corresponding increase in the price of vehicles.
# - Its show postive relationship between stroke and price.
# - Stroke sizes 2.8,2.9,3.1,4.1 as these stroke sizes are high, their prices are also high.
#
# #### 11.Relationship between Compression - Ratio & Price
# - In this graph some points, Vehicles with higher compression ratios indicate higher and lower price but On the other hand, a lower compression ratio could be car priced higher So there is not much of a trend here.
#
# #### 12.Relationship between Horsepower & Price
# - Vehicles with higher horsepower there tends corresponding increase in the price of vehicles otherwise price will be decrease.
# - The relationship between horsepower and price impact on vehicle pricing its show postive trends.
#
# #### 13.Relationship between Peak-rpm & Price
# - In this Graph it is seen that suddenly some points have high price and suddenly some points are showing low price of vehicles.
# - 4300,4600,5800 as these higher peak-rpm their prices are also high. In this case the graph no much tread are present.
#
# #### 14.Relationship between City-mpg & Price
# - city-MPG increases there tends corresponding decrease in the price.
# - city-MPG is lower that time the price of car is higher.
#
# #### 15.Relationship between Highway-mpg & Price
# - Highway-MPG increases there tends corresponding decrease in the price.
# - Highway-MPG is lower that time the price of car is higher.

# %%
plt.figure(figsize=(14,10),facecolor="white")
plotnumber=1

for column in cat_data.drop("Make",axis=1):
    if plotnumber<=len(cat_data):
        plt.subplot(3,3,plotnumber)
        sns.barplot(x=column ,y='Price',data=data)
        plt.xlabel(column,fontsize=15)
        plt.ylabel("Price",fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(14,7))
sns.barplot(x='Make',y='Price',data=data)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation/Insights
#
# #### 1.Relationship between Fuel Type & Price
# - Diesel vehicles generally have higher prices compared to gas vehicles. Gas vehicles are less expensive than diesel vehicles.
#
# #### 2.Relationship between Aspiration & Price
# - TurboCharged engine vehicles have higher prices compared to Standard engine vehicles.
#
# #### 3.Relationship between No-of-Doors & Price
# - Four door car model might have wider price range.on the other hand Two-door car models have higher price.
# - In this case there is not much difference between four door and two door car model price.
#
# #### 4.Relationship between Body-Style & Price
# - Convertible and Hardtop car model can refer higher price.
# - sedan car model are quite wider price as compared to Hatchback and wagon.
# - Hatchback and wagon are have lower price as compared to other body style.
#
# #### 5.Relationship between Drive-Wheels & Price
# - Rear-wheel drive vehicles having higher price.
# - Four-wheel drive vehicles having quite lower as compared to Rear-wheel drive vehicles and quite higher as compared to Front-wheel drive vehicles.
#
# #### 6.Relationship between Engine-Location & Price
# - Rear-engine vehicles can lead to higher price.
# - Front-engine vehicles are the most common its refer lower price.
#
# #### 7.Relationship between Engine-Type & Price
# - Engine types like DOHC and OHCV are having higher price as compared to other Engine-Types.
# - I engine type price is quite higher compared to OHC, rotor, ohcf Engine type.
#
# #### 8.Relationship between No-of-Cylinders & Price
# - Vehicles with higher numbers of cylinders, such as 6, 8, or 12 cylinders,justify higher prices.
# - Vehicles with 5-cylinder engines are quite higher prices compared to 2, 3, 4 Cylinders in vehicles.
#
# #### 9.Relationship between Fuel-System & Price
# - Vehicles with Fuel-System of MPFI and IDI having higher prices as comapred to other fuel system.
# - MPI, 4BBi, SPFI and SPDI fewer are higher then MPFI and IDI.
#
# #### 10.Relationship between Make & Price
# - Jaguar,Mercedes-Benz,Porsche and BMW car Brand having higher price. as compared to other cars

# %% [markdown]
# ### 3. Multivariate Data Analysis

# %%
sns.scatterplot(x=data["Length"],y=data["Price"],hue=data["Num-of-Doors"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# - Maximum number of vehicles have four doors and its length is more and price is high as compared to vehicles which have two doors and its length is less and price is also less.

# %%
sns.scatterplot(x=data["Compression-Ratio"],y=data["Price"],hue=data["Fuel-Type"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# - If the Fuel Type is Gas there comparession ratio is low and most of the time price is low

# %%
sns.scatterplot(x=data["Wheel-Base"],y=data["Price"],hue=data["Drive-Wheels"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# * If the wheel base is high at that time drive wheels with RWD are high price.

# %%
sns.scatterplot(x=data["Horsepower"],y=data["Price"],hue=data["Aspiration"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# - Maximum number of vehicles have std aspiration and its horsepower is incresing and price is high as compared to vehicles which have turbo aspiration.

# %%
sns.scatterplot(x=data["Engine-Size"],y=data["Price"],hue=data["Engine-Location"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# - Maximum number of vehicles have front engine location and its engine size is more and price is high as compared to vehicles which have rear engine location.

# %%
sns.scatterplot(x=data["Length"],y=data["Price"],hue=data["Body-Style"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# - In this graph there are more "sedan" body styles and the length of the vehicles of that body style is also more and accordindly the price is also increasing.

# %%
sns.scatterplot(x=data["Horsepower"],y=data["Price"],hue=data["Engine-Type"],s=30)
plt.show()

# %% [markdown]
# #### Observation/Insights
# * If the horsepower is low at that time engine type is ohc most of the time as well as car prie also less.

# %% [markdown]
# ### DATA PREPROCESSING

# %% [markdown]
# #### 1. HANDLE MISSING VALUES

# %%
data.isnull().sum()
# Out:
# Symboling             0
# Normalized-Losses    37
# Make                  0
# Fuel-Type             0
# Aspiration            0
# Num-of-Doors          2
# Body-Style            0
# Drive-Wheels          0
# Engine-Location       0
# Wheel-Base            0
# Length                0
# Width                 0
# Height                0
# Curb-Weight           0
# Engine-Type           0
# Num-Of-Cylinders      0
# Engine-Size           0
# Fuel-System           0
# Bore                  4
# Stroke                4
# Compression-Ratio     0
# Horsepower            2
# Peak-rpm              2
# City-mpg              0
# Highway-mpg           0
# Price                 0
# dtype: int64

# %% [markdown]
# * Normalized-Losses, No-Of-Doors, Bore, Stroke, HorsePower and Peak-rpm have missing values present in these features.

# %% [markdown]
# #### 1. Normalized-Losses

# %%
sns.histplot(x=data["Normalized-Losses"],kde=True)
plt.show()

# %%
data["Normalized-Losses"].median()
# Out:
# 115.0

# %%
data.loc[data["Normalized-Losses"].isnull()==True,"Normalized-Losses"] = data["Normalized-Losses"].median()

# %% [markdown]
# #### 2. No-Of-Doors

# %%
data["Num-of-Doors"].mode()
# Out:
# 0    four
# Name: Num-of-Doors, dtype: object

# %%
data.loc[data["Num-of-Doors"].isnull()==True,"Num-of-Doors"]="four"

# %% [markdown]
# #### 3. Bore

# %%
sns.histplot(x=data["Bore"],kde=True)
plt.show()

# %%
data["Bore"].median()
# Out:
# 3.31

# %%
data.loc[data["Bore"].isnull()==True,"Bore"]=data["Bore"].median()

# %% [markdown]
# #### 4. Stroke

# %%
sns.histplot(x=data["Stroke"],kde=True)
plt.show()

# %%
data["Stroke"].median()
# Out:
# 3.29

# %%
data.loc[data["Stroke"].isnull()==True,"Stroke"]=data["Stroke"].median()

# %% [markdown]
# #### 5. Horsepower

# %%
sns.histplot(x=data["Horsepower"],kde=True)
plt.show()

# %%
data["Horsepower"].median()
# Out:
# 95.0

# %%
data.loc[data["Horsepower"].isnull()==True,"Horsepower"]=data["Horsepower"].median()

# %% [markdown]
# #### 6. Peak-rpm

# %%
sns.histplot(x=data["Peak-rpm"],kde=True)
plt.show()

# %%
data["Peak-rpm"].median()
# Out:
# 5200.0

# %%
data.loc[data["Peak-rpm"].isnull()==True,"Peak-rpm"]=data["Peak-rpm"].median()

# %%
data.isnull().sum()
# Out:
# Symboling            0
# Normalized-Losses    0
# Make                 0
# Fuel-Type            0
# Aspiration           0
# Num-of-Doors         0
# Body-Style           0
# Drive-Wheels         0
# Engine-Location      0
# Wheel-Base           0
# Length               0
# Width                0
# Height               0
# Curb-Weight          0
# Engine-Type          0
# Num-Of-Cylinders     0
# Engine-Size          0
# Fuel-System          0
# Bore                 0
# Stroke               0
# Compression-Ratio    0
# Horsepower           0
# Peak-rpm             0
# City-mpg             0
# Highway-mpg          0
# Price                0
# dtype: int64

# %% [markdown]
# #### 2. HANDLE CATEGORICAL DATA

# %% [markdown]
# #### 1. Fule-Type

# %%
data["Fuel-Type"].value_counts()
# Out:
# gas       181
# diesel     20
# Name: Fuel-Type, dtype: int64

# %%
data["Fuel-Type"]=data["Fuel-Type"].map({"diesel":0,"gas":1})

# %% [markdown]
# #### 2. Aspiration

# %%
data["Aspiration"].value_counts()
# Out:
# std      165
# turbo     36
# Name: Aspiration, dtype: int64

# %%
data.Aspiration=data.Aspiration.map({"turbo":0,"std":1})

# %% [markdown]
# #### 3. Num-of-Doors

# %%
data["Num-of-Doors"].value_counts()
# Out:
# four    115
# two      86
# Name: Num-of-Doors, dtype: int64

# %%
data["Num-of-Doors"]=data["Num-of-Doors"].map({"two":0,"four":1})

# %% [markdown]
# #### 4. Drive-Wheels

# %%
data["Drive-Wheels"].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: Drive-Wheels, dtype: int64

# %%
data["Drive-Wheels"]=data["Drive-Wheels"].map({"4wd":0,"rwd":1,"fwd":2})

# %% [markdown]
# #### 5. Engine-Location

# %%
data["Engine-Location"].value_counts()
# Out:
# front    198
# rear       3
# Name: Engine-Location, dtype: int64

# %%
data["Engine-Location"]=data["Engine-Location"].map({"rear":0,"front":1})

# %% [markdown]
# #### 6. Body-Style

# %%
data["Body-Style"].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: Body-Style, dtype: int64

# %%
data.loc[data["Body-Style"]=='sedan','Body-Style']=4
data.loc[data["Body-Style"]=='hatchback','Body-Style']=3
data.loc[data["Body-Style"]=='wagon',"Body-Style"]=2
data.loc[data["Body-Style"]=='hardtop',"Body-Style"]=1
data.loc[data["Body-Style"]=='convertible',"Body-Style"]=0

# %% [markdown]
# #### 7. Engine-Type

# %%
data["Engine-Type"].value_counts()
# Out:
# ohc      145
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# Name: Engine-Type, dtype: int64

# %%
data.loc[data["Engine-Type"]=='ohc','Engine-Type']=5
data.loc[data["Engine-Type"]=='ohcf','Engine-Type']=4
data.loc[data["Engine-Type"]=='ohcv','Engine-Type']=3
data.loc[data["Engine-Type"]=='dohc',"Engine-Type"]=2
data.loc[data["Engine-Type"]=='l',"Engine-Type"]=1
data.loc[data["Engine-Type"]=='rotor',"Engine-Type"]=0

# %% [markdown]
# #### 8. Num-of-Cylinders

# %%
data["Num-Of-Cylinders"].value_counts()
# Out:
# four      157
# six        24
# five       10
# two         4
# eight       4
# three       1
# twelve      1
# Name: Num-Of-Cylinders, dtype: int64

# %%
data.loc[data["Num-Of-Cylinders"]=='four','Num-Of-Cylinders']=6
data.loc[data["Num-Of-Cylinders"]=='six','Num-Of-Cylinders']=5
data.loc[data["Num-Of-Cylinders"]=='five','Num-Of-Cylinders']=4
data.loc[data["Num-Of-Cylinders"]=='eight','Num-Of-Cylinders']=3
data.loc[data["Num-Of-Cylinders"]=='two',"Num-Of-Cylinders"]=2
data.loc[data["Num-Of-Cylinders"]=='three',"Num-Of-Cylinders"]=1
data.loc[data["Num-Of-Cylinders"]=='twelve',"Num-Of-Cylinders"]=0

# %% [markdown]
# #### 9. Fuel-System

# %%
data["Fuel-System"].value_counts()
# Out:
# mpfi    92
# 2bbl    64
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: Fuel-System, dtype: int64

# %%
data.loc[data["Fuel-System"]=='mpfi','Fuel-System']=7
data.loc[data["Fuel-System"]=='2bbl','Fuel-System']=6
data.loc[data["Fuel-System"]=='idi','Fuel-System']=5
data.loc[data["Fuel-System"]=='1bbl','Fuel-System']=4
data.loc[data["Fuel-System"]=='spdi','Fuel-System']=3
data.loc[data["Fuel-System"]=='4bbl',"Fuel-System"]=2
data.loc[data["Fuel-System"]=='spfi',"Fuel-System"]=1
data.loc[data["Fuel-System"]=='mfi',"Fuel-System"]=0

# %% [markdown]
# #### 10. Make

# %%
data["Make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: Make, dtype: int64

# %%
data.loc[data["Make"]=='toyota','Make']=21
data.loc[data["Make"]=='nissan','Make']=20
data.loc[data["Make"]=='mazda','Make']=19
data.loc[data["Make"]=='mitsubishi','Make']=18
data.loc[data["Make"]=='honda','Make']=17
data.loc[data["Make"]=='volkswagen','Make']=16
data.loc[data["Make"]=='subaru','Make']=15
data.loc[data["Make"]=='peugot','Make']=14
data.loc[data["Make"]=='volvo','Make']=13
data.loc[data["Make"]=='dodge','Make']=12
data.loc[data["Make"]=='mercedes-benz','Make']=11
data.loc[data["Make"]=='bmw','Make']=10
data.loc[data["Make"]=='plymouth','Make']=9
data.loc[data["Make"]=='audi','Make']=8
data.loc[data["Make"]=='saab','Make']=7
data.loc[data["Make"]=='porsche','Make']=6
data.loc[data["Make"]=='jaguar','Make']=5
data.loc[data["Make"]=='chevrolet','Make']=4
data.loc[data["Make"]=='alfa-romero','Make']=3
data.loc[data["Make"]=='isuzu','Make']=2
data.loc[data["Make"]=='renault','Make']=1
data.loc[data["Make"]=='mercury','Make']=0

# %% [markdown]
# #### 3. HANDLE OUTLIER

# %%
plt.figure(figsize=(16,20),facecolor="white")
plotnumber=1

for column in num_data.drop("Price",axis=1):
    if plotnumber<=len(num_data):
        plt.subplot(5,3,plotnumber)
        sns.boxplot(x=num_data[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel("count",fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20),facecolor="white")
plotnumber=1

for column in num_data.drop("Price",axis=1):
    if plotnumber<=len(num_data):
        plt.subplot(5,3,plotnumber)
        sns.histplot(x=data[column],kde=True)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### 1. Normalized-Losses

# %%
Q1=data["Normalized-Losses"].quantile(0.25)
Q3=data["Normalized-Losses"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 101.0
# upper quartile 137.0
# IQR is 36.0
# Lower limit is 47.0
# Upper limit is 191.0

# %%
data.loc[data["Normalized-Losses"]>upper_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 9            2              192.0   10          1           1             0
# 10           0              192.0   10          1           1             1
# 101          3              194.0   20          1           1             0
# 102          3              194.0   20          1           0             0
# 103          1              231.0   20          1           1             0
# 174          3              197.0   21          1           1             0
# 175          3              197.0   21          1           1             0
# 186          3              256.0   16          1           1             0
#
#     Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 9            4             1                1       101.2   176.8   64.8
# 10           4             1                1       101.2   176.8   64.8
# ...

# %%
len(data.loc[data["Normalized-Losses"]>upper_limit])/len(data)
# Out:
# 0.03980099502487562

# %%
data.loc[data["Normalized-Losses"]>upper_limit,"Normalized-Losses"]=data["Normalized-Losses"].median()

# %%
data.loc[data["Normalized-Losses"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 2. Wheel-Base

# %%
Q1=data["Wheel-Base"].quantile(0.25)
Q3=data["Wheel-Base"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 94.5
# upper quartile 102.4
# IQR is 7.900000000000006
# Lower limit is 82.64999999999999
# Upper limit is 114.25000000000001

# %%
data.loc[data["Wheel-Base"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 67         -1               93.0   11          0           0             1
# 68         -1              115.0   11          1           1             1
# 70          0              115.0   11          1           1             1
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 67          4             1                1       115.6   202.6   71.7
# 68          4             1                1       115.6   202.6   71.7
# 70          4             1                1       120.9   208.1   71.7
#
#     Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size Fuel-System  \
# 67    56.3         3770           5                4          183           5
# 68    56.5         3740           3                3          234           7
# 70    56.7         3900           3                3          308           7
#
# ...

# %%
len(data.loc[data["Wheel-Base"]>upper_limit])/len(data)
# Out:
# 0.014925373134328358

# %%
data.loc[data["Wheel-Base"]>upper_limit,"Wheel-Base"]=data["Wheel-Base"].median()

# %%
data.loc[data["Wheel-Base"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 3. Length

# %%
# lower_limit
lower_limit=data["Length"].mean()-3*data["Length"].std()
print("Lower_limit",lower_limit)

# upper_limit
upper_limit=data["Length"].mean()+3*data["Length"].std()
print("Upper_limit",upper_limit)
# Out:
# Lower_limit 137.2344697480152
# Upper_limit 211.16752030173646

# %%
data.loc[data["Length"]>upper_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %%
data.loc[data["Length"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 4. Width

# %%
Q1=data["Width"].quantile(0.25)
Q3=data["Width"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 64.1
# upper quartile 66.6
# IQR is 2.5
# Lower limit is 60.349999999999994
# Upper limit is 70.35

# %%
data.loc[data["Width"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 6           1              158.0    8          1           1             1
# 7           1              115.0    8          1           1             1
# 8           1              158.0    8          1           0             1
# 16          0              115.0   10          1           1             1
# 46          0              115.0    5          1           1             0
# 67         -1               93.0   11          0           0             1
# 68         -1              115.0   11          1           1             1
# 69          3              142.0   11          1           1             0
# 70          0              115.0   11          1           1             1
# 71          1              115.0   11          1           1             0
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# ...

# %%
len(data.loc[data["Width"]>upper_limit])/len(data)
# Out:
# 0.04975124378109453

# %%
data.loc[data["Width"]>upper_limit,"Width"]=data["Width"].median()

# %%
data.loc[data["Width"]<lower_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 17          2              121.0    4          1           1             0
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 17          3             2                1        88.4   141.1   60.3
#
#     Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size Fuel-System  \
# 17    53.2         1488           1                1           61           6
#
#     Bore  Stroke  Compression-Ratio  Horsepower  Peak-rpm  City-mpg  \
# 17  2.91    3.03                9.5        48.0    5100.0        47
#
#     Highway-mpg  Price
# 17           53   5151

# %%
len(data.loc[data["Width"]<lower_limit])/len(data)
# Out:
# 0.004975124378109453

# %%
data.loc[data["Width"]<lower_limit,"Width"]=data["Width"].median()

# %%
data.loc[data["Width"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 5. Curb-Weight

# %%
Q1=data["Curb-Weight"].quantile(0.25)
Q3=data["Curb-Weight"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 2169.0
# upper quartile 2926.0
# IQR is 757.0
# Lower limit is 1033.5
# Upper limit is 4061.5

# %%
data.loc[data["Curb-Weight"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 44          0              145.0    5          1           1             1
# 45          0              115.0    5          1           1             1
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 44          4             1                1       113.0   199.6   69.6
# 45          4             1                1       113.0   199.6   69.6
#
#     Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size Fuel-System  \
# 44    52.8         4066           2                5          258           7
# 45    52.8         4066           2                5          258           7
#
#     Bore  Stroke  Compression-Ratio  Horsepower  Peak-rpm  City-mpg  \
# 44  3.63    4.17                8.1       176.0    4750.0        15
# 45  3.63    4.17                8.1       176.0    4750.0        15
#
#     Highway-mpg  Price
# 44           19  32250
# 45           19  35550

# %%
len(data.loc[data["Curb-Weight"]>upper_limit])/len(data)
# Out:
# 0.009950248756218905

# %%
data.loc[data["Curb-Weight"]>upper_limit,"Curb-Weight"]=data["Curb-Weight"].median()

# %%
data.loc[data["Curb-Weight"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 6. Engine-Size

# %%
Q1=data["Engine-Size"].quantile(0.25)
Q3=data["Engine-Size"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 98.0
# upper quartile 141.0
# IQR is 43.0
# Lower limit is 33.5
# Upper limit is 205.5

# %%
data.loc[data["Engine-Size"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 14          0              115.0   10          1           1             1
# 15          0              115.0   10          1           1             0
# 16          0              115.0   10          1           1             1
# 44          0              145.0    5          1           1             1
# 45          0              115.0    5          1           1             1
# 46          0              115.0    5          1           1             0
# 68         -1              115.0   11          1           1             1
# 69          3              142.0   11          1           1             0
# 70          0              115.0   11          1           1             1
# 71          1              115.0   11          1           1             0
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# ...

# %%
len(data["Engine-Size"]>upper_limit)/len(data)
# Out:
# 1.0

# %%
data.loc[data["Engine-Size"]>upper_limit,"Engine-Size"]=data["Engine-Size"].median()

# %%
data.loc[data["Engine-Size"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 7. Stroke

# %%
Q1=data["Stroke"].quantile(0.25)
Q3=data["Stroke"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 3.11
# upper quartile 3.41
# IQR is 0.30000000000000027
# Lower limit is 2.6599999999999993
# Upper limit is 3.8600000000000003

# %%
data.loc[data["Stroke"]>upper_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 28           3              145.0   12          1           0             0
# 44           0              145.0    5          1           1             1
# 45           0              115.0    5          1           1             1
# 126          0              115.0    1          1           1             1
# 127          2              115.0    1          1           1             0
#
#     Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 28           3             2                1        95.9   173.2   66.3
# 44           4             1                1       113.0   199.6   69.6
# 45           4             1                1       113.0   199.6   69.6
# 126          2             2                1        96.1   181.5   66.5
# 127          3             2                1        96.1   176.8   66.6
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# ...

# %%
len(data.loc[data["Stroke"]>upper_limit])/len(data)
# Out:
# 0.024875621890547265

# %%
data.loc[data["Stroke"]>upper_limit,"Stroke"]=data["Stroke"].median()

# %%
data.loc[data["Stroke"]<lower_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 108          0              161.0   14          1           1             1
# 110          0              115.0   14          1           1             1
# 130          3              150.0    7          1           1             0
# 134          2               83.0   15          1           1             0
# 135          2               83.0   15          1           1             0
# 136          2               83.0   15          1           1             0
# 137          0              102.0   15          1           1             1
# 138          0              102.0   15          1           1             1
# 139          0              102.0   15          1           1             1
# 140          0              102.0   15          1           1             1
# 141          0              102.0   15          1           0             1
# ...

# %%
len(data.loc[data["Stroke"]<lower_limit])/len(data)
# Out:
# 0.07462686567164178

# %%
data.loc[data["Stroke"]<lower_limit,"Stroke"]=data["Stroke"].median()

# %% [markdown]
# #### 8. Compression-Ratio

# %%
Q1=data["Compression-Ratio"].quantile(0.25)
Q3=data["Compression-Ratio"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 8.6
# upper quartile 9.4
# IQR is 0.8000000000000007
# Lower limit is 7.399999999999999
# Upper limit is 10.600000000000001

# %%
data.loc[data["Compression-Ratio"]>upper_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 46           0              115.0    5          1           1             0
# 60           0              115.0   19          0           1             1
# 63           0              115.0   19          0           1             1
# 64          -1               93.0   11          0           0             1
# 65          -1               93.0   11          0           0             1
# 66           0               93.0   11          0           0             0
# 67          -1               93.0   11          0           0             1
# 87           1              128.0   20          0           1             0
# 105          0              161.0   14          0           0             1
# 107          0              115.0   14          0           0             1
# 109          0              161.0   14          0           0             1
# ...

# %%
len(data.loc[data["Compression-Ratio"]>upper_limit])/len(data)
# Out:
# 0.1044776119402985

# %%
data.loc[data["Compression-Ratio"]>upper_limit,"Compression-Ratio"]=data["Compression-Ratio"].median()

# %%
data.loc[data["Compression-Ratio"]<lower_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 28           3              145.0   12          1           0             0
# 79           3              115.0   18          1           0             0
# 80           3              115.0   18          1           0             0
# 81           3              115.0   18          1           0             0
# 114          0              161.0   14          1           0             1
# 121          3              115.0    9          1           0             0
#
#     Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 28           3             2                1        95.9   173.2   66.3
# 79           3             2                1        95.9   173.2   66.3
# 80           3             2                1        95.9   173.2   66.3
# 81           3             2                1        95.9   173.2   66.3
# ...

# %%
data.loc[data["Compression-Ratio"]<lower_limit,"Compression-Ratio"] = data["Compression-Ratio"].median()

# %% [markdown]
# #### 9. Horsepower

# %%
Q1=data["Horsepower"].quantile(0.25)
Q3=data["Horsepower"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 70.0
# upper quartile 116.0
# IQR is 46.0
# Lower limit is 1.0
# Upper limit is 185.0

# %%
data.loc[data["Horsepower"]>upper_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 46           0              115.0    5          1           1             0
# 102          3              115.0   20          1           0             0
# 123          3              115.0    6          1           1             0
# 124          3              115.0    6          1           1             0
# 125          3              115.0    6          1           1             0
#
#     Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 46           4             1                1       102.0   191.7   65.5
# 102          3             1                1        91.3   170.7   67.9
# 123          1             1                0        89.5   168.9   65.0
# 124          1             1                0        89.5   168.9   65.0
# 125          0             1                0        89.5   168.9   65.0
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# ...

# %%
len(data.loc[data["Horsepower"]>upper_limit])/len(data)
# Out:
# 0.024875621890547265

# %%
data.loc[data["Horsepower"]>upper_limit,"Horsepower"]=data["Horsepower"].median()

# %%
data.loc[data["Horsepower"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 10.Peak-rpm

# %%
Q1=data["Peak-rpm"].quantile(0.25)
Q3=data["Peak-rpm"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 4800.0
# upper quartile 5500.0
# IQR is 700.0
# Lower limit is 3750.0
# Upper limit is 6550.0

# %%
data.loc[data["Peak-rpm"]>upper_limit]
# Out:
#      Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 161          1              168.0   21          1           1             0
# 162          1              168.0   21          1           1             0
#
#     Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 161          4             1                1        94.5   168.7   64.0
# 162          3             1                1        94.5   168.7   64.0
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# 161    52.6         2265           2                6           98
# 162    52.6         2300           2                6           98
#
#     Fuel-System  Bore  Stroke  Compression-Ratio  Horsepower  Peak-rpm  \
# 161           7  3.24    3.08                9.4       112.0    6600.0
# 162           7  3.24    3.08                9.4       112.0    6600.0
#
#      City-mpg  Highway-mpg  Price
# 161        26           29   9298
# ...

# %%
len(data.loc[data["Peak-rpm"]>upper_limit])/len(data)
# Out:
# 0.009950248756218905

# %%
data.loc[data["Peak-rpm"]>upper_limit,"Peak-rpm"]=data["Peak-rpm"].median()

# %%
data.loc[data["Peak-rpm"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 11. City-mpg

# %%
Q1=data["City-mpg"].quantile(0.25)
Q3=data["City-mpg"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 19.0
# upper quartile 30.0
# IQR is 11.0
# Lower limit is 2.5
# Upper limit is 46.5

# %%
data.loc[data["City-mpg"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 17          2              121.0    4          1           1             0
# 29          2              137.0   17          1           1             0
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 17          3             2                1        88.4   141.1   65.5
# 29          3             2                1        86.6   144.6   63.9
#
#     Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size Fuel-System  \
# 17    53.2         1488           1                1           61           6
# 29    50.8         1713           5                6           92           4
#
#     Bore  Stroke  Compression-Ratio  Horsepower  Peak-rpm  City-mpg  \
# 17  2.91    3.03                9.5        48.0    5100.0        47
# 29  2.91    3.41                9.6        58.0    4800.0        49
#
#     Highway-mpg  Price
# 17           53   5151
# 29           54   6479

# %%
len(data.loc[data["City-mpg"]>upper_limit])/len(data)
# Out:
# 0.009950248756218905

# %%
data.loc[data["City-mpg"]>upper_limit,"City-mpg"]=data["City-mpg"].median()

# %%
data.loc[data["City-mpg"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# #### 12. Highway-mpg

# %%
Q1=data["Highway-mpg"].quantile(0.25)
Q3=data["Highway-mpg"].quantile(0.75)

print("lower quartile",Q1)
print("upper quartile",Q3)

IQR=Q3-Q1
print(f"IQR is",IQR)

lower_limit=Q1-1.5*IQR
print("Lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("Upper limit is",upper_limit)
# Out:
# lower quartile 25.0
# upper quartile 34.0
# IQR is 9.0
# Lower limit is 11.5
# Upper limit is 47.5

# %%
data.loc[data["Highway-mpg"]>upper_limit]
# Out:
#     Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 17          2              121.0    4          1           1             0
# 29          2              137.0   17          1           1             0
# 87          1              128.0   20          0           1             0
#
#    Body-Style  Drive-Wheels  Engine-Location  Wheel-Base  Length  Width  \
# 17          3             2                1        88.4   141.1   65.5
# 29          3             2                1        86.6   144.6   63.9
# 87          4             2                1        94.5   165.3   63.8
#
#     Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size Fuel-System  \
# 17    53.2         1488           1                1           61           6
# 29    50.8         1713           5                6           92           4
# 87    54.5         2017           5                6          103           5
#
# ...

# %%
len(data.loc[data["Highway-mpg"]>upper_limit])/len(data)
# Out:
# 0.014925373134328358

# %%
data.loc[data["Highway-mpg"]>upper_limit,"Highway-mpg"]=data["Highway-mpg"].median()

# %%
data.loc[data["Highway-mpg"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Symboling, Normalized-Losses, Make, Fuel-Type, Aspiration, Num-of-Doors, Body-Style, Drive-Wheels, Engine-Location, Wheel-Base, Length, Width, Height, Curb-Weight, Engine-Type, Num-Of-Cylinders, Engine-Size, Fuel-System, Bore, Stroke, Compression-Ratio, Horsepower, Peak-rpm, City-mpg, Highway-mpg, Price]
# Index: []

# %% [markdown]
# ### 4. SCALING

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data[["Normalized-Losses","Wheel-Base","Length","Height","Bore","Stroke","Compression-Ratio","Horsepower","Peak-rpm","Width","Curb-Weight","Highway-mpg","Engine-Size"]] = sc.fit_transform(data[["Normalized-Losses","Wheel-Base","Length","Height","Bore","Stroke","Compression-Ratio","Horsepower","Peak-rpm","Width","Curb-Weight","Highway-mpg","Engine-Size"]])

# %%
data.head(2)
# Out:
#    Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 0          3          -0.078008    3          1           1             0
# 1          3          -0.078008    3          1           1             0
#
#   Body-Style  Drive-Wheels  Engine-Location  Wheel-Base    Length     Width  \
# 0          0             1                1   -1.767358 -0.439409 -0.929196
# 1          0             1                1   -1.767358 -0.439409 -0.929196
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# 0 -2.034081     0.017775           2                6     0.353915
# 1 -2.034081     0.017775           2                6     0.353915
#
#   Fuel-System      Bore    Stroke  Compression-Ratio  Horsepower  Peak-rpm  \
# 0           7  0.522405 -3.073608           0.159223    0.330522 -0.230442
# 1           7  0.522405 -3.073608           0.159223    0.330522 -0.230442
#
#    City-mpg  Highway-mpg  Price
# 0        21    -0.536437  13495
# ...

# %% [markdown]
# ### FEATURE ENGINERING

# %% [markdown]
# #### 1. CHECK CORRELATION

# %%
data.corr()
# Out:
#                    Symboling  Normalized-Losses      Make  Fuel-Type  \
# Symboling           1.000000           0.397375 -0.086115   0.196735
# Normalized-Losses   0.397375           1.000000 -0.134948   0.082447
# Make               -0.086115          -0.134948  1.000000  -0.049689
# Fuel-Type           0.196735           0.082447 -0.049689   1.000000
# Aspiration          0.054615          -0.012585  0.127027   0.408228
# Num-of-Doors       -0.672344          -0.299921  0.008334  -0.186681
# Body-Style         -0.301383           0.072321  0.052201  -0.108892
# Drive-Wheels        0.107764          -0.082498  0.165609   0.056508
# Engine-Location    -0.212339           0.009602  0.201303  -0.040917
# Wheel-Base         -0.516528          -0.056758 -0.126363  -0.294959
# Length             -0.365404          -0.021312 -0.239075  -0.211187
# Width              -0.241247           0.006297 -0.173425  -0.302849
# Height             -0.550160          -0.322548  0.003308  -0.281578
# ...

# %%
plt.figure(figsize=(22,22))
sns.heatmap(data.corr(),annot=True,cmap="YlGnBu",annot_kws={"size":15})
plt.show()

# %% [markdown]
# * From above heat map we seen that highway-mpg & city-mpg has high correlation, for that reason we drop any one feature.

# %%
data.drop("City-mpg",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#    Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 0          3          -0.078008    3          1           1             0
# 1          3          -0.078008    3          1           1             0
#
#   Body-Style  Drive-Wheels  Engine-Location  Wheel-Base    Length     Width  \
# 0          0             1                1   -1.767358 -0.439409 -0.929196
# 1          0             1                1   -1.767358 -0.439409 -0.929196
#
#      Height  Curb-Weight Engine-Type Num-Of-Cylinders  Engine-Size  \
# 0 -2.034081     0.017775           2                6     0.353915
# 1 -2.034081     0.017775           2                6     0.353915
#
#   Fuel-System      Bore    Stroke  Compression-Ratio  Horsepower  Peak-rpm  \
# 0           7  0.522405 -3.073608           0.159223    0.330522 -0.230442
# 1           7  0.522405 -3.073608           0.159223    0.330522 -0.230442
#
#    Highway-mpg  Price
# 0    -0.536437  13495
# 1    -0.536437  16500

# %% [markdown]
# #### 2. CHECK DUPLICATES VALUES

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * There are no duplicate values are present in entired data

# %%
data.head()
# Out:
#    Symboling  Normalized-Losses Make  Fuel-Type  Aspiration  Num-of-Doors  \
# 0          3          -0.078008    3          1           1             0
# 1          3          -0.078008    3          1           1             0
# 2          1          -0.078008    3          1           1             0
# 3          2           1.773320    8          1           1             1
# 4          2           1.773320    8          1           1             1
#
#   Body-Style  Drive-Wheels  Engine-Location  Wheel-Base    Length     Width  \
# 0          0             1                1   -1.767358 -0.439409 -0.929196
# 1          0             1                1   -1.767358 -0.439409 -0.929196
# 2          3             1                1   -0.713342 -0.244152 -0.076094
# 3          4             2                1    0.233485  0.195176  0.350457
# 4          4             0                1    0.162026  0.195176  0.472328
#
# ...

# %%
categorical_columns = ['Make', 'Fuel-Type', 'Aspiration', 'Num-of-Doors', 'Body-Style',
       'Drive-Wheels', 'Engine-Location', 'Engine-Type', 'Num-Of-Cylinders',
       'Fuel-System']
"""data[categorical_columns] = data[categorical_columns].astype('numeric')
data[categorical_columns] = data[categorical_columns].apply(lambda x: x.cat.codes)
data = data.astype(float)"""
data[categorical_columns] = data[categorical_columns].astype(int)

# %% [markdown]
# ## MODEL CREATION & EVALUATION
#
# ### Models:
# 1. Linear Regression
# 2. Decision Tree Regressor
# 3. XGB Regressor

# %% [markdown]
# ### DEFINE INDEPENDANT AND DEPENDANT FEATURES

# %%
X = data.iloc[:,:-1]
y = data.Price

# %% [markdown]
# ### SPLITE TRANING AND TESTING DATA

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
X_train.shape
# Out:
# (160, 24)

# %%
X_test.shape
# Out:
# (41, 24)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (41,)

# %% [markdown]
# ### MODEL BUILDING

# %% [markdown]
# ### 1. LINEAR REGRESSION

# %%
from sklearn. linear_model import LinearRegression

# Initialize Linear Regressor model
Lin_reg = LinearRegression()

# Fit training data
Lin_reg.fit(X_train,y_train)

# Make predictions on test data
Lin_pred=Lin_reg.predict(X_test)

# %%
# slopes/coefficients of x
Lin_reg.coef_
# Out:
# array([-1.16888845e+01,  9.61051068e+01, -1.06386448e+02, -5.24079475e+03,
#         1.85668258e+03, -6.20075989e+01,  1.48418201e+02,  9.94255169e+00,
#        -2.73069756e+04,  1.21559503e+03,  3.43208677e+02,  1.27800188e+02,
#        -9.88044681e+02,  3.18416313e+03,  1.25151590e+03, -1.67019432e+03,
#        -2.48955735e+03,  3.64385962e+02, -1.83446513e+01, -5.87098839e+02,
#        -1.19919244e+02,  3.62207270e+03, -8.95788793e+02, -8.00331193e+02])

# %%
# Intercept
Lin_reg.intercept_
# Out:
# 46378.81478097828

# %% [markdown]
# ### EVALUATION

# %% [markdown]
# #### R-2_SCORE

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
Lin_R2_score=r2_score(y_test,Lin_pred)
Lin_R2_score
# Out:
# 0.9021956007029492

# %% [markdown]
# #### ADJUSTED R-2_SCORE

# %%
Lin_Adj_R2_score=1-(1-Lin_R2_score)*(41-1)/(41-24-1)
Lin_Adj_R2_score
# Out:
# 0.7554890017573731

# %% [markdown]
# **1. MEAN SQUARED ERROR(MSE)**

# %%
MSE=mean_squared_error(y_test,Lin_pred)
MSE
# Out:
# 6562922.700217358

# %% [markdown]
# **2. MEAN ABSOLUTE ERROR(MAE)**

# %%
MAE=mean_absolute_error(y_test,Lin_pred)
MAE
# Out:
# 2037.1226624809483

# %% [markdown]
# **3. ROOT MEAN SQUARED ERROR(RMSE)**

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 2561.8201927960044

# %% [markdown]
# ### 2. DECISION TREE REGRESSION

# %%
from sklearn.tree import DecisionTreeRegressor

# Initialize Decision Tree Regressor model
tree_regressor = DecisionTreeRegressor()

# Fit training data
tree_regressor.fit(X_train, y_train)

# Make predictions on test data
DTR_pred = tree_regressor.predict(X_test)

# Make predictions on train data 
DTR_train_pred = tree_regressor.predict(X_train)

# %% [markdown]
# ### EVALUATION

# %% [markdown]
# #### R-2_SCORE

# %%
DTR_R2_score=r2_score(y_test,DTR_pred)
DTR_R2_score
# Out:
# 0.89796916390585

# %% [markdown]
# #### ADJUSTED R-2_SCORE

# %%
DTR_Adj_R2_score=1-(1-DTR_R2_score)*(41-1)/(41-24-1)
DTR_Adj_R2_score
# Out:
# 0.744922909764625

# %% [markdown]
# **1. MEAN SQUARED ERROR(MSE)**

# %%
MSE=mean_squared_error(y_test,DTR_pred)
MSE
# Out:
# 6846527.304878049

# %% [markdown]
# **2. MEAN ABSOLUTE ERROR(MAE)**

# %%
MAE=mean_absolute_error(y_test,DTR_pred)
MAE
# Out:
# 1663.1951219512196

# %% [markdown]
# **3. ROOT MEAN SQUARED ERROR(RMSE)**

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 2616.586957255204

# %% [markdown]
# ### MODEL SAVING

# %%
import pickle

file = open('Linear_Regression_model.pkl','wb')
pickle.dump(Lin_reg,file)

# %% [markdown]
# ### 3. XGBOOST REGRESSION

# %%
from xgboost import XGBRegressor

# Initialize the XGBoost regression model
XGB_model = XGBRegressor()

# Train the model with training data
XGB_model.fit(X_train, y_train)

# Test the model with testing data
y_pred = XGB_model.predict(X_test)

# %% [markdown]
# ### EVALUATION

# %% [markdown]
# #### R-2_SCORE

# %%
XGB_R2_score=r2_score(y_test,y_pred)
XGB_R2_score
# Out:
# 0.9124039333633933

# %% [markdown]
# #### ADJUSTED R-2_SCORE

# %%
XGB_Adj_R2_score=1-(1-XGB_R2_score)*(41-1)/(41-24-1)
XGB_Adj_R2_score
# Out:
# 0.7810098334084833

# %% [markdown]
# **1. MEAN SQUARED ERROR(MSE)**

# %%
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 5877917.74512206

# %% [markdown]
# **2. MEAN ABSOLUTE ERROR(MAE)**

# %%
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1463.356778772866

# %% [markdown]
# **3. ROOT MEAN SQUARED ERROR(RMSE)**

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 2424.441738859084

# %% [markdown]
# ### HYPERPARAMETER TUNNING

# %%
from sklearn.model_selection import RandomizedSearchCV

grid_params= {'gamma':[0,0.1,0.2,0.4,0.8,1.6,3.2,6.4,12.8,25.6,51.2,102.4,200,230,300],
             "learning_rate":[0.01,0.03,0.06,0.1,0.15,0.2,0.25,0.300000012,0.4,0.5,0.6,0.7,0.9],
              "max_depth":[5,6,7,8,9,10,11,12,14,20],
             "n_estimators":[50,65,80,100,115,130,150,170,200],
             "reg_alpha":[0,0.,0.2,0.4,0.8,.6,3.2,6.4,12.8,25.6,51.2,200,290,300],
             "reg_lambda":[0.1,0.2,0.4,0.8,1.6,3.2,6.4,12.8,25.6,51.2,200,105,160]}

XGB_Tune_model = XGBRegressor()
XGB_Tune_Grid=RandomizedSearchCV(XGB_model,grid_params,cv=3,verbose=2,scoring="neg_mean_squared_error",n_jobs=-1,random_state=2023,n_iter=100)

XGB_Tune_Grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
# ...

# %%
print(XGB_Tune_Grid.best_params_)
# Out:
# {'reg_lambda': 51.2, 'reg_alpha': 25.6, 'n_estimators': 150, 'max_depth': 20, 'learning_rate': 0.6, 'gamma': 102.4}

# %%
XGB_Tune_Grid=XGBRegressor(reg_lambda= 51.2, reg_alpha= 25.6, n_estimators= 150, max_depth=20, learning_rate = 0.6, gamma = 102.4)
XGB_Tune_Grid.fit(X_train,y_train)
XGB_y_pred=XGB_Tune_Grid.predict(X_test)
XGB_y_train_pred=XGB_Tune_Grid.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
XGB_R2_score=r2_score(y_test,XGB_y_pred)
XGB_R2_score
# Out:
# 0.9228916453355709

# %%
XGB_Adj_R2_score=1-(1-XGB_R2_score)*(41-1)/(41-24-1)
XGB_Adj_R2_score
# Out:
# 0.8072291133389272

# %%
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 5877917.74512206

# %%
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1463.356778772866

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 2424.441738859084

# %%
import pickle
XGB_FILE =open("XGB_REGRESSOR.pkl","wb")
pickle.dump(XGB_Tune_model,XGB_FILE)

# %% [markdown]
# #### ConClusion:
# * From above all three model XGB Regressor is perform well for that reason we are select XGB Regressor.

# %% [markdown]
# #### --------------------------------------------------------------------------- Thank You ---------------------------------------------------------------------------
